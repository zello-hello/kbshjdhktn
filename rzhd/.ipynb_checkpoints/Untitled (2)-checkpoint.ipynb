# %%
import pandas as pd

# %%
project = pd.read_csv('Реестр проектов .xlsx - Проекты КБШ.csv')
project
# Out:
#                                                                                                                                                                    Номер;Название проекта;Описание проекта;Компания;Ф.И.О.;телефон;Текущий статус;
# 1    Система аналитики дислокации работников            Система позволяющая оповещать работников о приб... ООО N146291 Новиков Л.Ф. 8(790)-197-50-64 П ДМВ Т НБТ                                         17.Внедрение
# 2    Антиобледенительные системы Форс                   В отличие от  большинства гидрофобных покрытий ... ООО N966118 Егоров Х.Д.  8(979)-553-80-67 ДЭЗ ДПО                                             17.Внедрение
# 3    «Осуществление опробования тормозов на основе т... Разработка технологии применения сокращенного о... ООО N179491 Морозов Г.И. 8(405)-945-58-27 Т                                                   17.Внедрение
# ...

# %%
project.dropna(how='all', inplace=True)
project.dropna(how='all', axis=1)
# Out:
#                                                                                                                                                                      Номер;Название проекта;Описание проекта;Компания;Ф.И.О.;телефон;Текущий статус;
# 1   Система аналитики дислокации работников            Система позволяющая оповещать работников о приб... ООО N146291 Новиков Л.Ф.    8(790)-197-50-64 П ДМВ Т НБТ                                         17.Внедрение
# 2   Антиобледенительные системы Форс                   В отличие от  большинства гидрофобных покрытий ... ООО N966118 Егоров Х.Д.     8(979)-553-80-67 ДЭЗ ДПО                                             17.Внедрение
# 3   «Осуществление опробования тормозов на основе т... Разработка технологии применения сокращенного о... ООО N179491 Морозов Г.И.    8(405)-945-58-27 Т                                                   17.Внедрение
# ...

# %%
project.columns = [ 'Номер', 
                    'Название проекта',
                    'Описание проекта',
                    'Информация о заявителе инновационного предложения (Компания)',
                    'Информация о заявителе инновационного предложения (ФИО)',
                    'Информация о заявителе инновационного предложения (Телефон)',
                    'Функциональный заказчик',
                    'Текущий статус']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/g9/vv2y68d12zb2z2k19st3t1sr0000gn/T/ipykernel_5857/2998203489.py in <module>
# ----> 1 project.columns = [ 'Номер',
#       2                     'Название проекта',
#       3                     'Описание проекта',
#       4                     'Информация о заявителе инновационного предложения (Компания)',
#       5                     'Информация о заявителе инновационного предложения (ФИО)',
#
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ...

# %%
project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 992 entries, (1, 'Система аналитики дислокации работников', 'Система позволяющая оповещать работников о приближении подвижного состава и информирования руководителя работ об удалении работников на безопасное расстояние от пути проследования подвижного состава;', 'ООО N146291', 'Новиков Л.Ф.', '8(790)-197-50-64', 'П ДМВ Т НБТ  ') to (992, 'Удаленное управление козловыми контейнерными кранами ', nan, 'ООО N857832', 'Ахмедшафин Х.А.', '8(703)-980-58-85', 'ДМ     ')
# Data columns (total 1 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Номер;Название проекта;Описание проекта;Компания;Ф.И.О.;телефон;Текущий статус;  992 non-null    object
# dtypes: object(1)
# memory usage: 246.8+ KB

# %%
project = project.iloc[4:994]
project.set_index('Номер', inplace=True)
project
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/g9/vv2y68d12zb2z2k19st3t1sr0000gn/T/ipykernel_5857/4132128838.py in <module>
#       1 project = project.iloc[4:994]
# ----> 2 project.set_index('Номер', inplace=True)
#       3 project
#
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# ...

# %%
def dict_project_database_creation(data):
    """
    Функция принимает на вход базу данных с проектами, в которой есть колонки "Название проекта", "Описание проекта":
    Функиция возвращает словарь слов со второстепенным значением и добавляет в исходные данные колонки со словарями (тегами)
    и их общим количеством в документе
    """
    
    def dict_creation(array):
        cur_dict = {}
        for i_array in range(len(array)):
            for i_words in array[i_array]:
                if len(i_words)>2:
                    i_words = i_words[:-3]
                else:
                    i_words = ''
                cur_dict[i_words] = array[i_array].count(i_words)
        return cur_dict
    
    data['Описание проекта тэги'] = dict_creation(list(map(lambda x: str(x).strip().split(' '), data['Описание проекта'])))
    data['Название проекта тэги'] = dict_creation(list(map(lambda x: str(x).strip().split(' '), data['Название проекта'])))
    
    return data

# %%
dict_project_database_creation(project)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/PycharmProjects/rzhd/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Описание проекта'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def dict_creation(array):
    cur_dict = {}
    for i_array in range(len(array)):
        for i_words in array[i_array]:
            if len(i_words)>2:
                i_words = i_words[:-3]
            else:
                i_words = ''
            cur_dict[i_words] = array[i_array].count(i_words)
    return cur_dict
dict_creation(list(map(lambda x: str(x).strip().split(' '), ['Система аналитики дислокации работников','Антиобледенительные системы Форс','«Осуществление опробования тормозов на основе',])))
# Out:
# {'Сист': 0,
#  'аналит': 0,
#  'дислока': 0,
#  'работни': 0,
#  'Антиобледенитель': 0,
#  'сист': 0,
#  'Ф': 0,
#  '«Осуществле': 0,
#  'опробова': 0,
#  'тормо': 0,
#  '': 0,
#  'осн': 0}

# %%
project
# Out:
#                                         Название проекта  \
# Номер
# 1                Система аналитики дислокации работников
# 2                       Антиобледенительные системы Форс
# 3      «Осуществление опробования тормозов на основе ...
# 4      Система промывки систем отопления зданий «БУЧА-К»
# 5      Обслуживание робототехнических комплексов разл...
# ...                                                  ...
# 986    NOVA Band мониторинг здоровья, активности и бе...
# 987               Интеллектуальное управление освещением
# 988                               Антикоррозийная защита
# 989    Вещество, предотвращающее отложение гололеда н...
# 990    Биомикрогели для очистки воды от масел, жиров ...
#
#                                         Описание проекта  \
# Номер
# 1      Система позволяющая оповещать работников о при...
# 2      В отличие от  большинства гидрофобных покрытий...
# 3      Разработка технологии применения сокращенного ...
# ...

# %%
project.to_dict('data_project.csv')
# Out:
# c:\users\михаил\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# {'Название проекта': {'1': 'Система аналитики дислокации работников',
#   '2': 'Антиобледенительные системы Форс',
#   '3': '«Осуществление опробования тормозов на основе технических средств без участия человека» СИПТМ-395 ',
#   '4': 'Система промывки систем отопления зданий «БУЧА-К»',
#   '5': 'Обслуживание робототехнических комплексов различного назначения, сенсорных и проводных систем и программного обеспечения',
#   '6': 'Окраска локомотива краской с добавлением нанодисперсного политетрафторэтилена',
#   '7': 'Информационное моделирование  BIM для сложных отраслевых технологических объектов транспортной компании, для линейных протяженных объектов',
# ...
